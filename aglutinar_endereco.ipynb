# %%
import sqlite3
import pandas as pd
import os
import zipfile
import io
import funcs.treatment as treat

# %%
DB_PATH = "dados_receita.db"

DB_NAME_IN = "RMSP"

DB_NAME_OUT = "RMSP_endereco_tratado"

# %%
treat.aglutinar_endereco(DB_PATH, DB_NAME_IN, DB_NAME_OUT)
# Out:
# ✓ VIEW 'RMSP_endereco_tratado' atualizada. Colunas redundantes removidas.

# %%
treat.validacao(DB_PATH, DB_NAME_OUT)
# Out:
# ...
# COLUNAS PRESENTES: ['cnae_fiscal_principal', 'cnae_fiscal_secundaria', 'cnpj_completo', 'razao_social', 'natureza_juridica', 'qualificacao_responsavel', 'capital_social', 'porte_empresa', 'ente_federativo_responsavel', 'matriz_filial', 'situacao_cadastral', 'data_situacao_cadastral', 'nome_cidade_exterior', 'pais', 'data_inicio_atividade', 'complemento', 'situacao_especial', 'data_situacao_especial', 'endereco_completo']
# ...
#
# RECORTE DAS PRIMEIRAS 5 LINHAS DA TABELA 'RMSP_endereco_tratado':
#
# [Registro 1]
#   cnae_fiscal_principal    : 4774100
#   cnae_fiscal_secundaria   : None
#   cnpj_completo            : 45368743000157
#   razao_social             : TOSHIMI NISHIMURA
#   natureza_juridica        : Empresário (Individual)
#   qualificacao_responsavel : Empresário
#   capital_social           : 0.0
#   porte_empresa            : MICRO EMPRESA
#   ente_federativo_responsavel: None
#   matriz_filial            : Matriz
#   situacao_cadastral       : 8
# ...
