# %%
import os
import sqlite3
import pandas as pd
import funcs.select_by as select_by
from tqdm import tqdm

# %%
# Entradas

filtro_uf = "CE"

filtro_CNAEs_principais = ""

DB_PATH = R"C:\Users\Mateus Joter\Desktop\CNPJ\dados_receita.db"

csv_entrada = ""

# %%
if not os.path.exists(DB_PATH):
    select_by.carregar_dataframe_sqlite(csv_entrada, DB_PATH_entrada)
    
    select_by.UF(DB_PATH, filtro_uf)
    
    select_by.main_CNAE(DB_PATH, filtro_CNAEs_principais)

else:
    select_by.UF(DB_PATH, filtro_uf)
    
    select_by.main_CNAE(DB_PATH, filtro_CNAEs_principais)
